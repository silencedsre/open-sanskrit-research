# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

model = AutoModelForSeq2SeqLM.from_pretrained("Swamitucats/M2M100_Sanskrit_English")
tokenizer = AutoTokenizer.from_pretrained("Swamitucats/M2M100_Sanskrit_English")

sanskrit_text = "विश्वामित्रवचः श्रुत्वा राघवः सहलक्ष्मणः। विस्मयं परमं गत्वा विश्वामित्रमथाब्रवीत्॥"
inputs = tokenizer(sanskrit_text, return_tensors="pt")
outputs = model.generate(**inputs)
english_translation = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(english_translation)
# Out:
# Hearing Viśvāmitra's words, Rāghava along with Lakşmaņa became exceedingly astonished and thus spoke to Viśvāmitra.

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Load model and tokenizer
print("Loading model and tokenizer...")
model = AutoModelForSeq2SeqLM.from_pretrained("Swamitucats/M2M100_Sanskrit_English")
tokenizer = AutoTokenizer.from_pretrained("Swamitucats/M2M100_Sanskrit_English")
print("Model loaded successfully!\n")

# Sample Sanskrit texts for testing - Mahabharata & Ramayana
test_samples = [
    # MAHABHARATA
    {
        "text": "धृतराष्ट्र उवाच। धर्मक्षेत्रे कुरुक्षेत्रे समवेता युयुत्सवः। मामकाः पाण्डवाश्चैव किमकुर्वत सञ्जय॥",
        "source": "Mahabharata - Bhagavad Gita 1.1",
        "context": "Dhritarashtra's opening question about the battle"
    },
    {
        "text": "यदा यदा हि धर्मस्य ग्लानिर्भवति भारत। अभ्युत्थानमधर्मस्य तदात्मानं सृजाम्यहम्॥",
        "source": "Mahabharata - Bhagavad Gita 4.7",
        "context": "Krishna on divine incarnation"
    },
    {
        "text": "कर्मण्येवाधिकारस्ते मा फलेषु कदाचन। मा कर्मफलहेतुर्भूर्मा ते सङ्गोऽस्त्वकर्मणि॥",
        "source": "Mahabharata - Bhagavad Gita 2.47",
        "context": "Famous verse on karma yoga"
    },
    {
        "text": "सत्यं ब्रूयात् प्रियं ब्रूयात् न ब्रूयात् सत्यमप्रियम्। प्रियं च नानृतं ब्रूयात् एष धर्मः सनातनः॥",
        "source": "Mahabharata - Udyoga Parva",
        "context": "Principles of truthful speech"
    },
    {
        "text": "अहिंसा परमो धर्मः धर्म हिंसा तथैव च। तस्मात् धर्मः परो राजन् सर्वेषामिव वै मतः॥",
        "source": "Mahabharata - Shanti Parva",
        "context": "On non-violence and righteous violence"
    },
    
    # RAMAYANA
    {
        "text": "विश्वामित्रवचः श्रुत्वा राघवः सहलक्ष्मणः। विस्मयं परमं गत्वा विश्वामित्रमथाब्रवीत्॥",
        "source": "Ramayana - Bala Kanda",
        "context": "Rama and Lakshmana listening to Vishwamitra"
    },
    {
        "text": "रामो विग्रहवान् धर्मः साधुः सत्यपराक्रमः। राजा सर्वस्य लोकस्य देवानामिव वासवः॥",
        "source": "Ramayana - Ayodhya Kanda",
        "context": "Description of Rama's virtues"
    },
    {
        "text": "न जातु कामान्न भयान्न लोभाद् धर्मं त्यजेयं प्राणैरपि गुरीयसम्। न जीवितस्याकाङ्क्षा मे न च राज्यस्य कर्हिचित्॥",
        "source": "Ramayana - Ayodhya Kanda",
        "context": "Rama's commitment to dharma"
    },
    {
        "text": "मातृदेवो भव पितृदेवो भव आचार्यदेवो भव अतिथिदेवो भव।",
        "source": "Ramayana",
        "context": "Respect for elders and guests"
    },
    {
        "text": "सीता मम प्राणेभ्योऽपि गरीयसी। जानकीमनृतामकृत्वा न शक्तः सुखमाप्तुम्॥",
        "source": "Ramayana - Aranya Kanda",
        "context": "Rama's love for Sita"
    }
]

# Function to translate
def translate_sanskrit(text):
    inputs = tokenizer(text, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=512)
    translation = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return translation

# Test all samples
print("="*80)
print("SANSKRIT TO ENGLISH TRANSLATION TESTS")
print("="*80)

for i, sample in enumerate(test_samples, 1):
    print(f"\n{'─'*80}")
    print(f"Test {i}: {sample['source']}")
    print(f"Context: {sample['context']}")
    print(f"{'─'*80}")
    print(f"\n📜 Sanskrit Text:")
    print(f"   {sample['text']}")
    print(f"\n🔄 Translating...")
    
    translation = translate_sanskrit(sample['text'])
    
    print(f"\n📖 English Translation:")
    print(f"   {translation}")
    print()

print("="*80)
print("Translation tests completed!")
print("="*80)
# Out:
# Loading model and tokenizer...
# Model loaded successfully!
#
# ================================================================================
# SANSKRIT TO ENGLISH TRANSLATION TESTS
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 1: Mahabharata - Bhagavad Gita 1.1
# Context: Dhritarashtra's opening question about the battle
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    धृतराष्ट्र उवाच। धर्मक्षेत्रे कुरुक्षेत्रे समवेता युयुत्सवः। मामकाः पाण्डवाश्चैव किमकुर्वत सञ्जय॥
#
# 🔄 Translating...
#
# 📖 English Translation:
#    Dhritarashtra said What did my warriors and the Pandavas do, O Srinjaya, with the desire of fighting, in the Kuru field of Dharma?
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 2: Mahabharata - Bhagavad Gita 4.7
# Context: Krishna on divine incarnation
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    यदा यदा हि धर्मस्य ग्लानिर्भवति भारत। अभ्युत्थानमधर्मस्य तदात्मानं सृजाम्यहम्॥
#
# 🔄 Translating...
#
# 📖 English Translation:
#    O descendant of Bharata, I create myself when virtue is destroyed and sin originates from it.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 3: Mahabharata - Bhagavad Gita 2.47
# Context: Famous verse on karma yoga
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    कर्मण्येवाधिकारस्ते मा फलेषु कदाचन। मा कर्मफलहेतुर्भूर्मा ते सङ्गोऽस्त्वकर्मणि॥
#
# 🔄 Translating...
#
# 📖 English Translation:
#    You have no right to act, nor to acquire fruits. You have no right to act for the fruits of your acts.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 4: Mahabharata - Udyoga Parva
# Context: Principles of truthful speech
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    सत्यं ब्रूयात् प्रियं ब्रूयात् न ब्रूयात् सत्यमप्रियम्। प्रियं च नानृतं ब्रूयात् एष धर्मः सनातनः॥
#
# 🔄 Translating...
#
# 📖 English Translation:
#    One should speak the truth; one should speak what is agreeable; one should never speak the truth which is disagreeable; one should never speak what is agreeable and what is untrue. This is the eternal religion.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 5: Mahabharata - Shanti Parva
# Context: On non-violence and righteous violence
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    अहिंसा परमो धर्मः धर्म हिंसा तथैव च। तस्मात् धर्मः परो राजन् सर्वेषामिव वै मतः॥
#
# 🔄 Translating...
#
# 📖 English Translation:
#    Abstention from injury is the highest duty. Virtue and abstention from injury are the highest duty. Therefore, O king, virtue is the highest duty.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 6: Ramayana - Bala Kanda
# Context: Rama and Lakshmana listening to Vishwamitra
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    विश्वामित्रवचः श्रुत्वा राघवः सहलक्ष्मणः। विस्मयं परमं गत्वा विश्वामित्रमथाब्रवीत्॥
#
# 🔄 Translating...
#
# 📖 English Translation:
#    Hearing Viśvāmitra's words, Rāghava along with Lakşmaņa became exceedingly astonished and thus spoke to Viśvāmitra.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 7: Ramayana - Ayodhya Kanda
# Context: Description of Rama's virtues
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    रामो विग्रहवान् धर्मः साधुः सत्यपराक्रमः। राजा सर्वस्य लोकस्य देवानामिव वासवः॥
#
# 🔄 Translating...
#
# 📖 English Translation:
#    Rāma is virtuous, righteous, truthful and possessed of prowess. He is the king of all the worlds like Vasava of the celestials.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 8: Ramayana - Ayodhya Kanda
# Context: Rama's commitment to dharma
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    न जातु कामान्न भयान्न लोभाद् धर्मं त्यजेयं प्राणैरपि गुरीयसम्। न जीवितस्याकाङ्क्षा मे न च राज्यस्य कर्हिचित्॥
#
# 🔄 Translating...
#
# 📖 English Translation:
#    Nor from desire, nor from fear, nor from covetousness, shall I renounce virtue, even if I live. I do not wish for life, nor for the kingdom.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 9: Ramayana
# Context: Respect for elders and guests
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    मातृदेवो भव पितृदेवो भव आचार्यदेवो भव अतिथिदेवो भव।
#
# 🔄 Translating...
#
# 📖 English Translation:
#    Be you the god of the mothers; be you the god of the Pitris; be you the preceptor; be you the god of guests; be you the god of guests.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Test 10: Ramayana - Aranya Kanda
# Context: Rama's love for Sita
# ────────────────────────────────────────────────────────────────────────────────
#
# 📜 Sanskrit Text:
#    सीता मम प्राणेभ्योऽपि गरीयसी। जानकीमनृतामकृत्वा न शक्तः सुखमाप्तुम्॥
#
# 🔄 Translating...
#
# 📖 English Translation:
#    Sītā is dearer to me than my life. Without speaking an untruth to Janaka's daughter, I am unable to attain to happiness.
#
# ================================================================================
# Translation tests completed!
# ================================================================================
